# %%
import pandas as pd
import numpy as np
import pymongo

pd.set_option('display.max_columns', 500)

# %%
db_name = 'guide_data'
service_collection_name = 'service'
company_collection_name = 'company'
deals_collection_name = 'deal'

conn = pymongo.MongoClient("mongodb://{}:{}@{}:{}/{}?authSource=admin".format('mongoadmin', '12345', 'localhost', '27017', db_name))

# %%
service_collection = lambda c: c[db_name][service_collection_name]
company_collection = lambda c: c[db_name][company_collection_name]
deals_collection = lambda c: c[db_name][deals_collection_name]

# %%
companies = pd.DataFrame(company_collection(conn).find())
cat_cols = ['got_support_from', 'did_get_support', 'service', 'stage_of_development', 'msp_category', 'is_export', 'inno_cluster_member', 'skolcovo_member', 'is_inno_company', 'is_startup']
companies[cat_cols] = companies[cat_cols].astype('category')
companies.drop(columns=['_id'], inplace=True)
companies.replace(['', 'н.д.'], np.nan, inplace=True)

# %%
companies.shape
# Out:
# (7347, 23)

# %%
deals = pd.DataFrame(deals_collection(conn).find())
deals[['round', 'deal_type']] = deals[['round', 'deal_type']].astype('category')
deals.drop(columns=['_id'], inplace=True)
deals.replace(['', 'н.д.'], np.nan, inplace=True)
deals = deals.applymap(lambda x: np.nan if isinstance(x, list) and len(x) == 0 else x)

# %%
deals.shape
# Out:
# (4546, 25)

# %%
services = pd.DataFrame(service_collection(conn).find())
services.drop(columns=['_id'], inplace=True)
services.replace(['', 'н.д.'], np.nan, inplace=True)

# %%
services.shape
# Out:
# (498, 26)

# %%
deals.head(2)
# Out:
#    deal_date  startup_name startup_inn gov_fund  gov_fund_sum_dol  \
# 0 2017-01-01        leadza  7721379557      NaN               0.0
# 1 2017-01-01  трансинфотех  7714858580      NaN               0.0
#
#    gov_fund_sum_rub private_fund  private_fund_sum_dol  private_fund_sum_rub  \
# 0               0.0       [фрии]         251551.654455            15000000.0
# 1               0.0          NaN              0.000000                   0.0
#
#           corp_fund  corp_fund_sum_dol  corp_fund_sum_rub corp_investor  \
# 0               NaN           0.000000                0.0           NaN
# 1  [коммит кэпитал]      670804.411881         40000000.0           NaN
#
#    corp_investor_sum_dol  corp_investor_sum_rub business_angel  \
# 0                    0.0                    0.0            NaN
# 1                    0.0                    0.0            NaN
#
#    business_angel_sum_dol  business_angel_sum_rub accelerator  \
# 0                     0.0                     0.0         NaN
# 1                     0.0                     0.0         NaN
#
#    accelerator_sum_dol  accelerator_sum_rub  final_price_dol  final_price_rub  \
# 0                  0.0                  0.0    251551.654455              0.0
# 1                  0.0                  0.0    670804.411881              0.0
#
#   round deal_type
# 0  seed       buy
# 1  seed       buy

# %%
present_inns = set(deals['startup_inn']) & set(companies['inn'])
len(present_inns)
# Out:
# 285

# %%
deals[deals['startup_inn'].apply(lambda x: x in present_inns)][['gov_fund', 'private_fund', 'corp_fund', 'corp_investor', 'business_angel', 'accelerator']].count()
# Out:
# gov_fund          181
# private_fund      947
# corp_fund         125
# corp_investor     489
# business_angel    472
# accelerator       375
# dtype: int64

# %%
# np.concatenate(deals.dropna(subset=['corp_investor'])['corp_investor'].values)

# %%
services.head(1)
# Out:
#           inn              name         type              startup_stage  \
# 0  7703638456  da vinci capital  VentureFund  [ранний рост, расширение]
#
#                                               market      services  \
# 0  [cybersecurity, transport & logistics, busines...  [инвестиции]
#
#                                         technologies type_of_ownership  \
# 0  [ar/vr, big data, блокчейн, интернет вещей, ис...           частный
#
#                investment_round  investition_from_dol  investition_to_dol  \
# 0  [раунд а, раунд в, раунд с+]             1000000.0          50000000.0
#
#   tech_focus  fund_total_rub  fund_total_dol  num_of_investments  \
# 0         []         25000.0           397.0                17.0
#
#    num_of_exits geography study_format  num_of_people_in_company_from  \
# 0           2.0       NaN          NaN                            NaN
#
#    num_of_people_in_company_to  num_of_participants okved_main  \
# 0                          NaN                  NaN        NaN
#
#   okved_secondary corp_stage business_model monetary_support
# 0             NaN        NaN            NaN              NaN

# %%
deals[deals['deal_type'] == 'buy'].head(1)
# Out:
#    deal_date startup_name startup_inn gov_fund  gov_fund_sum_dol  \
# 0 2017-01-01       leadza  7721379557      NaN               0.0
#
#    gov_fund_sum_rub private_fund  private_fund_sum_dol  private_fund_sum_rub  \
# 0               0.0       [фрии]         251551.654455            15000000.0
#
#   corp_fund  corp_fund_sum_dol  corp_fund_sum_rub corp_investor  \
# 0       NaN                0.0                0.0           NaN
#
#    corp_investor_sum_dol  corp_investor_sum_rub business_angel  \
# 0                    0.0                    0.0            NaN
#
#    business_angel_sum_dol  business_angel_sum_rub accelerator  \
# 0                     0.0                     0.0         NaN
#
#    accelerator_sum_dol  accelerator_sum_rub  final_price_dol  final_price_rub  \
# 0                  0.0                  0.0    251551.654455              0.0
#
#   round deal_type
# 0  seed       buy

# %%
def group_deals_by_investor_type():
    res = (deals[deals['deal_type'] == 'buy'].melt(id_vars=['startup_inn', 'round'], 
               value_vars=['gov_fund', 'private_fund', 'corp_fund', 'corp_investor', 'business_angel', 'accelerator'])
        .dropna()
        .groupby(['startup_inn', 'round'])['variable'].apply(pd.value_counts)
        .unstack().reset_index()
        .where(lambda x: x['startup_inn'].apply(lambda i: i in present_inns))
        .dropna(subset=['startup_inn'])
        .fillna(0).set_index(['startup_inn', 'round'])
        .apply(lambda x: x / x.sum(), axis=1))

    return res

companies_and_share_of_deals_by_fund_type = group_deals_by_investor_type()
companies_and_share_of_deals_by_fund_type.head()
# Out:
#                       accelerator  business_angel  corp_fund  corp_investor  \
# startup_inn round
# 1615013084  seed              1.0             0.0        0.0            0.0
# 1650350558  pre-seed          1.0             0.0        0.0            0.0
# 1650390180  pre-seed          1.0             0.0        0.0            0.0
# 1655449455  seed              0.0             0.0        0.0            0.0
# 1657238107  seed              0.0             1.0        0.0            0.0
#
#                       gov_fund  private_fund
# startup_inn round
# 1615013084  seed           0.0           0.0
# 1650350558  pre-seed       0.0           0.0
# 1650390180  pre-seed       0.0           0.0
# 1655449455  seed           0.0           1.0
# 1657238107  seed           0.0           0.0

# %%
companies_and_share_of_deals_by_fund_type.sum()
# Out:
# accelerator        61.166667
# business_angel     72.266667
# corp_fund          19.983333
# corp_investor      72.933333
# gov_fund           39.416667
# private_fund      105.233333
# dtype: float64

# %%
# companies_and_share_of_deals_by_fund_type.to_csv('type_classifier_target.csv')

# %%
(companies.where(lambda x: x['inn'].apply(lambda i: i in present_inns)).dropna(how='all')
).set_index('inn').to_csv('type_classifier_data.csv')

# %%
def try_concat(arr):
    try:
        return np.concatenate(arr)
    except Exception as e:
        return []

def match_company_and_investor():
    ff = (
        deals[deals['deal_type'] == 'buy']
        .groupby(['startup_inn', 'round'])[['gov_fund', 'private_fund', 'corp_fund', 'corp_investor', 'business_angel', 'accelerator']]
        .apply(lambda x: set(try_concat([i for i in x.values.reshape((-1, )) if isinstance(i, list)]))))

    investor_and_company = pd.DataFrame()

    for row in services.to_dict(orient='records'):
        inv_name = row['name']
        fit = ff.where(ff.apply(lambda x: inv_name in x)).dropna(how='all')
        if fit.empty is False:
    #         print("Match: ", fit.shape, row)
            investor_and_company = investor_and_company.append(pd.DataFrame({k: [v] * fit.shape[0] for k, v in row.items()}, index=fit.index))
    return investor_and_company.rename(columns=lambda x: '{}__investor'.format(x)).merge(
        companies.rename(columns=lambda x: '{}__company'.format(x)), left_on='startup_inn', right_on='inn__company')

# %%
company_and_its_investor = match_company_and_investor()

# %%
company_and_its_investor['type__investor'].value_counts()
# Out:
# VentureFund          376
# ProgressInstitute     15
# Accelerator           12
# Name: type__investor, dtype: int64

# %%
company_and_its_investor.head(3)
# Out:
#   inn__investor         name__investor type__investor  \
# 0    7703638456       da vinci capital    VentureFund
# 1    7728461088  new industry ventures    VentureFund
# 2    7728461088  new industry ventures    VentureFund
#
#                startup_stage__investor  \
# 0            [ранний рост, расширение]
# 1  [ранний рост, расширение, посевная]
# 2  [ранний рост, расширение, посевная]
#
#                                     market__investor services__investor  \
# 0  [cybersecurity, transport & logistics, busines...       [инвестиции]
# 1                                        [cleantech]       [инвестиции]
# 2                                        [cleantech]       [инвестиции]
#
#                               technologies__investor  \
# 0  [ar/vr, big data, блокчейн, интернет вещей, ис...
# 1  [3d моделирование, big data, интернет вещей, н...
# 2  [3d моделирование, big data, интернет вещей, н...
#
#   type_of_ownership__investor    investment_round__investor  \
# 0                     частный  [раунд а, раунд в, раунд с+]
# 1                     частный      [seed, раунд а, раунд в]
# 2                     частный      [seed, раунд а, раунд в]
#
#    investition_from_dol__investor  investition_to_dol__investor  \
# 0                       1000000.0                    50000000.0
# 1                        500000.0                     3000000.0
# 2                        500000.0                     3000000.0
#
#   tech_focus__investor  fund_total_rub__investor  fund_total_dol__investor  \
# 0                   []                   25000.0                     397.0
# 1                   []                    4000.0                      62.0
# 2                   []                    4000.0                      62.0
#
#    num_of_investments__investor  num_of_exits__investor geography__investor  \
# 0                          17.0                     2.0                 NaN
# 1                           1.0                     0.0                 NaN
# 2                           1.0                     0.0                 NaN
#
#   study_format__investor  num_of_people_in_company_from__investor  \
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
#
#    num_of_people_in_company_to__investor  num_of_participants__investor  \
# 0                                    NaN                            NaN
# 1                                    NaN                            NaN
# 2                                    NaN                            NaN
#
#    okved_main__investor  okved_secondary__investor  corp_stage__investor  \
# 0                   NaN                        NaN                   NaN
# 1                   NaN                        NaN                   NaN
# 2                   NaN                        NaN                   NaN
#
#    business_model__investor monetary_support__investor inn__company  \
# 0                       NaN                        NaN   7704794345
# 1                       NaN                        NaN   7714762021
# 2                       NaN                        NaN   7714762021
#
#         name__company    got_support_from__company did_get_support__company  \
# 0  ооо "геттакси рус"  карта инновационных решений                       да
# 1     ооо "скайер ит"       московский акселератор                      нет
# 2        ооо "радуга"  карта инновационных решений                       да
#
#                           service__company foundation_date__company  \
# 0  добавлено - карта инновационных решений               2011-11-03
# 1                   московский акселератор               2008-12-23
# 2  добавлено - карта инновационных решений               2008-12-23
#
#               tech_focus__company stage_of_development__company  \
# 0         [транспорт и логистика]                    расширение
# 1  [недвижимость и строительство]                   ранний рост
# 2  [недвижимость и строительство]                   ранний рост
#
#            market__company technology__company business_model__company  \
# 0  [transport & logistics]                  []                   [b2c]
# 1               [proptech]      [беспилотники]                   [b2b]
# 2               [proptech]      [беспилотники]                   [b2b]
#
#   main_okved__company                           okved_secondary__company  \
# 0               62.09  [82.99, 46.19, 63.11.1, 47.91.2, 69.20.2, 46.1...
# 1               72.19  [62.09, 85.42, 62.02, 63.11.1, 30.30.11, 63.11...
# 2               72.19  [62.09, 85.42, 62.02, 63.11.1, 30.30.11, 63.11...
#
#   msp_category__company is_export__company inno_cluster_member__company  \
# 0                   NaN                нет                           да
# 1              юл микро                нет                           да
# 2              юл микро                нет                           да
#
#   skolcovo_member__company is_inno_company__company is_startup__company  \
# 0                      нет                       да                 нет
# 1                       да                       да                 нет
# 2                       да                       да                 нет
#
#    current_profit__company  current_profit_tax__company  \
# 0                    -23.0                        -15.0
# 1                 -16450.0                          0.0
# 2                 -16450.0                          0.0
#
#    current_revenue__company type__company
# 0                    1507.0       Company
# 1                   19127.0       Company
# 2                   19127.0       Company

# %%
company_and_its_investor.to_csv('company_and_its_investor.csv')

# %%
services.where(services['name'].apply(lambda x: x in te)).dropna(how='all')
# Out:
#             inn                               name  \
# 0    7703638456                   da vinci capital
# 1    7728461088              new industry ventures
# 2             0                         addventure
# 3             0                     admitad invest
# 4             0                     altair capital
# ..          ...                                ...
# 125           0                           smarthub
# 126  9703026834                         dv capital
# 484  7703425673  российский фонд прямых инвестиций
# 485  7736004350         фонд содействия инновациям
# 489  7728131587                            роснано
#
#                            startup_stage  \
# 0              [ранний рост, расширение]
# 1    [ранний рост, расширение, посевная]
# 2              [ранний рост, расширение]
# 3                [ранний рост, посевная]
# 4    [ранний рост, расширение, посевная]
# ..                                   ...
# 125                     [идея, посевная]
# 126        [ранний рост, идея, посевная]
# 484                         [расширение]
# 485                              [любая]
# 489            [ранний рост, расширение]
#
#                                                 market  \
# 0    [cybersecurity, transport & logistics, busines...
# 1                                          [cleantech]
# 2    [hrtech, consumer goods & services, foodtech, ...
# 3    [business software, advertising & marketing, e...
# 4    [edtech, insurancetech, business software, e-c...
# ..                                                 ...
# 125  [agrotech, cybersecurity, edtech, transport & ...
# 126  [agrotech, cybersecurity, edtech, transport & ...
# 484                                                NaN
# 485                                                NaN
# 489                                                NaN
#
#                                               services  \
# 0                                         [инвестиции]
# 1                                         [инвестиции]
# 2                                         [инвестиции]
# 3    [инвестиции, консультационная поддержка по раз...
# 4    [инвестиции, консультационная поддержка по раз...
# ..                                                 ...
# 125  [инвестиции, консультационная поддержка по раз...
# 126  [инвестиции, консультационная поддержка по раз...
# 484  [инвестиции, обучение (образовательные програм...
# 485   [финансовая поддержка (субсидии, гранты и т.п.)]
# 489  [инвестиции, тестирование продукта, защита инт...
#
#                                           technologies type_of_ownership  \
# 0    [ar/vr, big data, блокчейн, интернет вещей, ис...           частный
# 1    [3d моделирование, big data, интернет вещей, н...           частный
# 2    [3d моделирование, ar/vr, big data, аддитивные...           частный
# 3    [ar/vr, искусственный интеллект и машинное обу...     корпоративный
# 4    [блокчейн, искусственный интеллект и машинное ...           частный
# ..                                                 ...               ...
# 125  [3d моделирование, ar/vr, big data, аддитивные...           частный
# 126  [3d моделирование, ar/vr, big data, аддитивные...           частный
# 484                                                NaN               NaN
# 485                                                NaN               NaN
# 489                                                NaN               NaN
#
#                  investment_round  investition_from_dol  investition_to_dol  \
# 0    [раунд а, раунд в, раунд с+]             1000000.0          50000000.0
# 1        [seed, раунд а, раунд в]              500000.0           3000000.0
# 2    [раунд а, раунд в, раунд с+]             1000000.0          10000000.0
# 3                 [seed, раунд а]              200000.0           2000000.0
# 4       [seed, раунд а, раунд с+]              100000.0          10000000.0
# ..                            ...                   ...                 ...
# 125              [pre-seed, seed]                   0.0                 0.0
# 126     [pre-seed, seed, раунд а]                   0.0                 0.0
# 484                           NaN                   NaN                 NaN
# 485                           NaN                   NaN                 NaN
# 489                           NaN                   NaN                 NaN
#
#     tech_focus  fund_total_rub  fund_total_dol  num_of_investments  \
# 0           []         25000.0           397.0                17.0
# 1           []          4000.0            62.0                 1.0
# 2           []             0.0             0.0                45.0
# 3           []             0.0             0.0                14.0
# 4           []         35000.0           500.0               271.0
# ..         ...             ...             ...                 ...
# 125         []             0.0             0.0                46.0
# 126         []             0.0             0.0                 4.0
# 484        NaN             NaN             NaN                 NaN
# 485        NaN             NaN             NaN                 NaN
# 489        NaN             NaN             NaN                 NaN
#
#      num_of_exits geography study_format  num_of_people_in_company_from  \
# 0             2.0       NaN          NaN                            NaN
# 1             0.0       NaN          NaN                            NaN
# 2             5.0       NaN          NaN                            NaN
# 3             0.0       NaN          NaN                            NaN
# 4            20.0       NaN          NaN                            NaN
# ..            ...       ...          ...                            ...
# 125           1.0       NaN          NaN                            NaN
# 126           0.0       NaN          NaN                            NaN
# 484           NaN       NaN          NaN                            NaN
# 485           NaN       NaN          NaN                            NaN
# 489           NaN       NaN          NaN                            NaN
#
#      num_of_people_in_company_to  num_of_participants okved_main  \
# 0                            NaN                  NaN        NaN
# 1                            NaN                  NaN        NaN
# 2                            NaN                  NaN        NaN
# 3                            NaN                  NaN        NaN
# 4                            NaN                  NaN        NaN
# ..                           ...                  ...        ...
# 125                          NaN                  NaN        NaN
# 126                          NaN                  NaN        NaN
# 484                          NaN                  NaN        NaN
# 485                          NaN                  NaN        NaN
# 489                          NaN                  NaN        NaN
#
#     okved_secondary corp_stage business_model  \
# 0               NaN        NaN            NaN
# 1               NaN        NaN            NaN
# 2               NaN        NaN            NaN
# 3               NaN        NaN            NaN
# 4               NaN        NaN            NaN
# ..              ...        ...            ...
# 125             NaN        NaN            NaN
# 126             NaN        NaN            NaN
# 484             NaN        NaN            NaN
# 485             NaN        NaN            NaN
# 489             NaN        NaN            NaN
#
#                                       monetary_support
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 125                                                NaN
# 126                                                NaN
# 484                                       [инвестиции]
# 485                                  [субсидии/гранты]
# 489  [инвестиции, гарантии/поручительства, займы/ к...
#
# [89 rows x 25 columns]
